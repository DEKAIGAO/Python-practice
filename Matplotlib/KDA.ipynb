# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

my_df = pd.DataFrame(randn(500,4),columns = ['Mon','Tues','Wed','Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.353113 -0.974702  0.468475  0.206622
# 1    1.155664  2.332920 -1.026377  0.519268
# 2    0.880145  0.812232 -2.024998 -0.653490
# 3    0.996800  1.111836  2.037409 -0.499121
# 4    0.440027 -0.423508 -0.339042 -1.426351
# ..        ...       ...       ...       ...
# 495 -0.762206  0.755224  0.991423  0.513457
# 496  0.812378 -0.348713 -0.095172 -0.848454
# 497 -0.935884 -1.561900 -1.186823 -0.954293
# 498  0.991599  1.927218  2.599561  1.063363
# 499 -0.170203 -0.723648  0.319945 -1.076709
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.kde(alpha = 0.4, grid = True)
# Out:
# <Axes: ylabel='Density'>
